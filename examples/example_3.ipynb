# %% [markdown]
# # Example 3 Input
# ## Each row is a separate message
# 1. Hello, my name is Lion, like the animal. My research interests lie in diffusion and computer vision. Can you help me find a supervisor please?
# 2. ../CVs/LionCV.pdf
# 3. no
# 4. I want something more related to theory of diffusion models, with practical uses in computer vision.
# 5. yes

# %%
import sys
sys.path.append('../')
from superwiser import SuperWiser

superwiser = SuperWiser()
superwiser.process()
# Out:
#
# 👋 Welcome to SuperWiser - Your AI Research Supervisor Assistant!
# Finding the right research supervisor can be tough, but I'm here to make it easier.
# I'll help you identify the best supervisor match based on your research interests, academic background, and preferences.
# Plus, I'll refine your CV and craft a professional email to make a strong first impression.
#
# To get started, just share:
# ✅ A brief description of your research interests and background
# ✅ A PDF of your CV (even if it's a draft)
#
# Let's find your perfect research supervisor together! 🚀
# SUPERVISOR RECOMMENDATION:
# Hello Lion, nice to meet you! Based on your interest in diffusion and computer vision, I think Professor Ayellet Tal could be an excellent fit for your research ambitions. Let me provide you with some insights into her work and how it aligns with your interests.
#
# ### Supervisor Overview: Professor Ayellet Tal
# ...
