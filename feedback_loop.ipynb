# %%
from agents.cv_feedback_agent import CVFeedback
from agents.cv_generator_agent import CVGenerator
import json

# %%
with open("parsed_cv.txt", "r", encoding="utf-8") as file:
    parsed_cv = file.read()

parsed_cv
# Out:
# '---\nEducation:\n- Master of Science in Data Science | Technion - Israel Institute of Technology | 2024–2026  \n- Bachelor of Science in Data Science | Technion - Israel Institute of Technology | 2021–2024  \n\nResearch Experience:\n- No information provided.\n\nWork Experience:\n- Teaching Assistant | Technion - Israel Institute of Technology | June 2024–Present (9 months)  \n  Description: Grading homework for the Probability M (094412) course.  \n- Student Aid | Technion - Israel Institute of Technology | October 2022–April 2023 & October 2024–Present (8 months)  \n  Description: Supported and guided first-year Data Science students.\n\nVolunteer Experience:\n- Lecturer | Technipwn CTF Group & Adversarial Attacks Course (02360207) | No specific years provided  \n  Description: Delivered lectures to students on adversarial attacks.\n\nPublications:\n- "Enhancing Jailbreak Attacks via Compliance-Refusal-Based Initialization" | Rom Himelstein | ICML25 | [Year not specified]  \n\nSkills:\n- Adversarial Attacks, Large Language Models, Data Science, Probability, Teaching, Research.\n\nAwards & Achievements:\n- Part of the "Alonim" excellence program in the IDF | IDF | No year provided  \n- Cum Laude (92.7 GPA) | Technion - Israel Institute of Technology | 2024  \n\nContact Information:\n- Name: Rom Himelstein  \n- Email: romh@campus.technion.ac.il  \n- Phone: 053-7176756  \n- LinkedIn: [linkedin.com/in/technion](https://linkedin.com/in/technion)  \n- Website: No information provided.  \n\n---'

# %%
with open("rag_response.txt", "r", encoding="utf-8") as file:
    rag_response = file.read()

rag_response
# Out:
# 'Hi Rom,\n\nThank you for sharing your background and research interests! Based on your focus on large language models (LLMs) and security, I’ve reviewed the profile of **Professor Avi Mendelson**, who appears to be a strong fit for your research aspirations. Let me break it down for you:\n\n---\n\n### **About Professor Avi Mendelson**\nProfessor Avi Mendelson is a leading researcher with expertise in computer systems, security, and hardware-software co-design. His work spans a wide range of topics, including cybersecurity for real-time systems, hardware reliability, and innovative approaches to addressing emerging challenges in computing architectures. His recent research also delves into the intersection of machine learning and security, which directly complements your interests in adversarial attacks and LLMs.\n\n---\n\n### **Key Research Areas**\nHere are some of the exciting areas Professor Mendelson focuses on:\n1. **Cybersecurity in Real-Time Systems**: His work on frameworks like SCART explores defending real-time systems (e.g., drones) against advanced cyberattacks, including sensor manipulations and behavioral disruptions. This aligns with your interest in adversarial techniques.\n   \n2. **Hardware Security**: Research on open-source hardware security, hardware Trojan detection, and side-channel attacks demonstrates his deep engagement in securing hardware platforms—critical for building trustworthy AI systems.\n\n3. **Machine Learning for Security**: \n   - His SCART framework integrates machine learning algorithms into drones\' navigation systems.\n   - His work on performance counters to perform side-channel attacks is highly relevant to understanding vulnerabilities in AI models and infrastructure.\n\n4. **Reliability of Computing Architectures**: Professor Mendelson tackles challenges like electromigration and asymmetric aging in microprocessors, ensuring they are robust and secure under extreme conditions.\n\n5. **Graph Neural Networks and Representation Learning**: While not directly security-focused, his work in graph neural networks (GNNs) and recoverability could contribute to novel ways of modeling and defending against adversarial attacks.\n\n---\n\n### **Why Professor Mendelson is a Great Fit for You**\n1. **Alignment with Your Expertise**:\n   - Your publication, *"Enhancing Jailbreak Attacks via Compliance-Refusal-Based Initialization"*, indicates a strong background in adversarial attacks and LLM vulnerabilities, which overlaps with Professor Mendelson’s interests in cyber threats and defense mechanisms.\n   - Your skills in adversarial attacks and teaching in this domain suggest you could contribute to and benefit from his projects on securing ML-driven systems.\n\n2. **Complementary Research Interests**:\n   - Professor Mendelson’s SCART framework and other security-focused projects demonstrate that he’s actively working on practical and theoretical challenges in cybersecurity, a field you’re passionate about.\n   - His expertise in hardware-software security could provide a unique perspective for exploring vulnerabilities in LLMs, especially in deployment contexts like edge devices or embedded systems.\n\n3. **Opportunities for Cross-Disciplinary Work**:\n   - Given your data science and LLM background, you could explore how large language models can be integrated into or secured within systems like those Professor Mendelson studies (e.g., drones, IoT devices).\n   - His ongoing work on automating reliability and security for hardware platforms could benefit from your insights into adversarial models and their interaction with infrastructure.\n\n---\n\n### **Next Steps**\nIf you’re interested in working with Professor Mendelson, here’s what I recommend:\n1. **Highlight Your Relevant Experience**: When reaching out, emphasize your expertise in adversarial attacks, LLMs, and security, as well as your teaching and publication record.\n2. **Propose Specific Ideas**:\n   - Suggest exploring the interse ...

# %%
user_input = "Hi, i'm Rom and I am looking for a superviser!! In the subject of LLMs and Security!!"

# %%
cv_generator_agent = CVGenerator(user_input, rag_response, parsed_cv)
cv_feedback_agent = CVFeedback()
# Out:
# /Users/eyaltadmor/Documents/סמסטר 7/SuperWiser2/agents/agent.py:20: LangChainDeprecationWarning: The class `AzureChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import AzureChatOpenAI``.
#   self.chat = AzureChatOpenAI(

# %%
accepted = False
feedback = None
counter = 0
while not accepted and counter < 3:
    counter += 1
    cv_generator_response = cv_generator_agent.generate_response(feedback=feedback)
    print(f"Generated CV: {cv_generator_response}")
    cv_feedback_response = cv_feedback_agent.generate_response(user_input, parsed_cv, cv_generator_response)

    cv_feedback = json.loads(cv_feedback_response)
    decision = cv_feedback["decision"]
    feedback = cv_feedback["feedback"]
    print(f"Desicion: {decision}")
    print(f"Feedback: {feedback}")
    if decision == "accept":
        accepted = True

if not accepted:
    print("CV generation failed, please try again.")
# Out:
# /Users/eyaltadmor/Documents/סמסטר 7/SuperWiser2/agents/agent.py:46: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = self.chat(messages=messages)
# Generated CV: ---
#
# Education:
# - Master of Science in Data Science | Technion - Israel Institute of Technology | 2024–2026
# - Bachelor of Science in Data Science | Technion - Israel Institute of Technology | 2021–2024
#
# Research Experience:
# - No information provided.
#
# Work Experience:
# - Teaching Assistant | Technion - Israel Institute of Technology | June 2024–Present
#   Description: Responsible for grading homework assignments for the Probability M (094412) course.
# - Student Aid | Technion - Israel Institute of Technology | October 2022–April 2023 & October 2024–Present
#   Description: Assisted and mentored first-year Data Science students, providing guidance and support in their academic journey.
#
# Volunteer Experience:
# - Lecturer | Technipwn CTF Group & Adversarial Attacks Course (02360207) | [No specific years provided]
#   Description: Presented lectures on adversarial attacks to students, sharing expertise and fostering understanding in the domain.
#
# Publications:
# - "Enhancing Jailbreak Attacks via Compliance-Refusal-Based Initialization" | Rom Himelstein | ICML25 | [Year not specified]
#
# Skills:
# - Adversarial Attacks, Large Language Models, Data Science, Probability, Teaching, Research.
#
# Awards & Achievements:
# - Member of the "Alonim" excellence program | IDF | [Year not specified]
# - Cum Laude (92.7 GPA) | Technion - Israel Institute of Technology | 2024
#
# Contact Information:
# - Name: Rom Himelstein
# - Email: romh@campus.technion.ac.il
# - Phone: 053-7176756
# - LinkedIn: [linkedin.com/in/technion](https://linkedin.com/in/technion)
# - Website: [Not provided]
#
# ---
# Desicion: reject
# Feedback: The generated CV is generally consistent with the previous CV draft but requires some revisions for accuracy and completeness:
#
# 1. **Work Experience**: The description for the 'Teaching Assistant' role is consistent but lacks a timeframe ('9 months') mentioned in the previous CV, which could provide additional clarity. Similarly, the 'Student Aid' role duration ('8 months') is missing, and this should be included for consistency.
#
# 2. **Volunteer Experience**: The years of involvement are still not specified. If the information is unavailable, it should clearly be stated as such (e.g., 'Dates not provided').
#
# 3. **Publications**: The year of the publication is still missing. If the year is unknown, it should be explicitly stated as 'Year not specified' rather than just leaving it blank in brackets.
#
# 4. **Awards & Achievements**: The award title 'Part of the "Alonim" excellence program in the IDF' has been slightly rephrased to 'Member of the "Alonim" excellence program | IDF'. While this is acceptable, the year of this achievement remains unspecified. Adding this detail would enhance the CV's completeness.
#
# 5. **Website**: Both the previous and generated CVs state 'Website: [Not provided]'. If this is a deliberate choice, it is fine. However, if a personal website exists, it should be included.
#
# 6. **Alignment with User Prompt**: The CV aligns well with the user's input about seeking a supervisor in LLMs and Security. However, the CV could benefit from explicitly emphasizing relevant work or research experience in these areas, if applicable.
#
# 7. **Formatting**: The formatting is consistent, but '[No specific years provided]' and '[Year not specified]' could be made uniform for consistency (e.g., use one phrase consistently throughout the CV).
# Generated CV: ---
#
# Education:
# - Master of Science in Data Science | Technion - Israel Institute of Technology | 2024–2026
# - Bachelor of Science in Data Science | Technion - Israel Institute of Technology | 2021–2024
#
# Research Experience:
# - No research experience provided.
#
# Work Experience:
# - Teaching Assistant | Technion - Israel Institute of Technology | June 2024–Present (9 months)
#   Description: Grading homework for the Probability M (094412) course.
# - Student Aid | Technion - Israel Institute of Technology | October 2022–April 2023 & October 2024–Present (8 months)
#   Description: Supported and guided first-year Data Science students.
#
# Volunteer Experience:
# - Lecturer | Technipwn CTF Group & Adversarial Attacks Course (02360207) | Dates not provided
#   Description: Delivered lectures to students on adversarial attacks.
#
# Publications:
# - "Enhancing Jailbreak Attacks via Compliance-Refusal-Based Initialization" | Rom Himelstein | ICML25 | Year not specified
#
# Skills:
# - Adversarial Attacks, Large Language Models, Data Science, Probability, Teaching, Research.
#
# Awards & Achievements:
# - Member of the "Alonim" excellence program | IDF | Year not specified
# - Cum Laude (92.7 GPA) | Technion - Israel Institute of Technology | 2024
#
# Contact Information:
# - Name: Rom Himelstein
# - Email: romh@campus.technion.ac.il
# - Phone: 053-7176756
# - LinkedIn: [linkedin.com/in/technion](https://linkedin.com/in/technion)
# - Website: Not provided
#
# ---
# Desicion: reject
# Feedback: The generated CV is largely consistent with the previous draft, but there are still areas that require improvement and clarification:
#
# 1. **Research Experience**: The prompt indicates interest in LLMs and Security, but the 'Research Experience' section is left blank in both the previous CV and the generated CV. If no formal research experience exists, the CV should include relevant coursework, projects, or contributions related to LLMs and security to strengthen alignment with the user's objective.
#
# 2. **Volunteer Experience**: The generated CV does not specify the years for the 'Lecturer' role, which is consistent with the previous CV. However, adding years would enhance clarity and credibility.
#
# 3. **Publications**: The publication 'Enhancing Jailbreak Attacks via Compliance-Refusal-Based Initialization' is listed without a specific year in both versions. As this is a critical piece of information, the year should be included for proper citation. Additionally, the journal/conference name 'ICML25' should be verified for accuracy, as it could be a typo or a placeholder.
#
# 4. **Awards & Achievements**: The 'Alonim' program entry lacks a specific year in both versions. Adding this detail would improve completeness.
#
# 5. **Customization for Objective**: The CV could be better tailored to reflect the user's interest in LLMs and Security. For example, the 'Skills' section could emphasize expertise in relevant areas like 'AI Security' or specific techniques/tools used in LLM research. Similarly, the user’s work or volunteer experience should highlight any overlap with these fields if applicable.
#
# 6. **Formatting Consistency**: The generated CV is consistent and well-structured, but small improvements in formatting (e.g., ensuring uniformity in how dates are presented) could enhance readability.
#
# Overall, while the generated CV is accurate and consistent with the previous draft, it does not fully address the user's goal of seeking a supervisor in LLMs and Security. Additional details and alignment with the objective are recommended.
# Generated CV: ---
#
# Education:
# - Master of Science in Data Science | Technion - Israel Institute of Technology | 2024–2026
# - Bachelor of Science in Data Science | Technion - Israel Institute of Technology | 2021–2024
#
# Research Experience:
# - [No formal research experience provided. Relevant coursework or projects can be added here.]
#
# Work Experience:
# - Teaching Assistant | Technion - Israel Institute of Technology | June 2024–Present (9 months)
#   Description: Grading homework for the Probability M (094412) course.
# - Student Aid | Technion - Israel Institute of Technology | October 2022–April 2023 & October 2024–Present (8 months)
#   Description: Supported and guided first-year Data Science students.
#
# Volunteer Experience:
# - Lecturer | Technipwn CTF Group & Adversarial Attacks Course (02360207) | [No specific years provided]
#   Description: Delivered lectures to students on adversarial attacks.
#
# Publications:
# - "Enhancing Jailbreak Attacks via Compliance-Refusal-Based Initialization" | Rom Himelstein | ICML25 | [Year not specified]
#
# Skills:
# - Adversarial Attacks, Large Language Models, Data Science, Probability, Teaching, Research
#
# Awards & Achievements:
# - Member of the "Alonim" excellence program | IDF | [Year not specified]
# - Cum Laude (92.7 GPA) | Technion - Israel Institute of Technology | 2024
#
# Contact Information:
# - Name: Rom Himelstein
# - Email: romh@campus.technion.ac.il
# - Phone: 053-7176756
# - LinkedIn: [linkedin.com/in/technion](https://linkedin.com/in/technion)
# - Website: [No information provided]
#
# ---
# Desicion: reject
# Feedback: The generated CV has maintained most of the information from the previous CV draft and is largely consistent. However, there are some issues that need to be addressed:
#
# 1. **Research Experience:** The generated CV includes '[No formal research experience provided. Relevant coursework or projects can be added here.]', which is unnecessary and detracts from the CV's professionalism. It would be better to omit this placeholder or include a specific project or coursework related to LLMs and Security, as Rom seeks a supervisor in this field.
#
# 2. **Volunteer Experience:** The generated CV does not resolve the issue of missing years for the 'Lecturer' role. The years should either be specified or the phrase '[No specific years provided]' should be removed for a cleaner presentation.
#
# 3. **Publications:** The year of publication for the listed ICML paper is still missing. This is a critical detail and should be added to improve credibility.
#
# 4. **Awards & Achievements:** The generated CV lists 'Member of the "Alonim" excellence program | IDF | [Year not specified]'. The year should be provided to enhance clarity and specificity.
#
# 5. **User Prompt Alignment:** Rom explicitly mentioned an interest in 'LLMs and Security'. The CV should highlight relevant skills, coursework, or experience in these areas. If such information is not available, it could be explicitly stated in a custom statement or objective section.
#
# 6. **Formatting:** The '[No information provided]' placeholder under 'Website' should be removed for a cleaner and more professional look.
#
# Overall, while the generated CV is consistent with the previous draft, it still has missing or placeholder information that diminishes its quality and alignment with the user's goals.
# CV generation failed, please try again.
