# %% [markdown]
# Example:
# * "Hello! I am interested in graphs and everything related to them. For example distributed computing on graphs and GNNs."
# * "YardenCV.pdf"

# %%
from superwiser import SuperWiser

superwiser = SuperWiser()
superwiser.process()
# Out:
# c:\Users\Rom\Desktop\Technion\Magister\Semester 1\TamirSeminar\Tirgulim\Project_Mitzi\agents\agent.py:20: LangChainDeprecationWarning: The class `AzureChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import AzureChatOpenAI``.
#   self.chat = AzureChatOpenAI(
# Ignoring wrong pointing object 6 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 12 0 (offset 0)
# Ignoring wrong pointing object 14 0 (offset 0)
# Ignoring wrong pointing object 16 0 (offset 0)
# Ignoring wrong pointing object 18 0 (offset 0)
# Ignoring wrong pointing object 20 0 (offset 0)
# Ignoring wrong pointing object 22 0 (offset 0)
# Ignoring wrong pointing object 24 0 (offset 0)
# c:\Users\Rom\Desktop\Technion\Magister\Semester 1\TamirSeminar\Tirgulim\Project_Mitzi\agents\agent.py:42: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = self.chat(messages=messages)
# Rejected CV, generating new one
# Rejected CV, generating new one
# Supervisor Recommendation:
# Hello Yarden Adi,
#
# Thank you for sharing your interests in graphs, distributed computing, and Graph Neural Networks (GNNs). Based on your academic background, skills, and achievements, I believe you have a solid foundation for pursuing research in these areas. Let me provide some insights into a potential supervisor who aligns with your interests.
#
# ---
#
# ### Supervisor Overview: Professor Ayellet Tal
# Professor Ayellet Tal is a prominent researcher at the Technion with interdisciplinary expertise spanning computer vision, machine learning, and computational geometry. Her body of work includes cutting-edge research on 3D point clouds, medical imaging, and deep learning, with applications in complex, data-rich environments. She has a strong focus on leveraging novel neural architectures and optimization techniques for various tasks, including anomaly detection, 3D object detection, and image-text representation.
#
# ---
#
# ### Key Research Areas and Interests:
# 1. **Graph-Based Learning and 3D Representation**:
#    - Several of Professor Tal's works, such as "CloudWalker" and "MeshWalker," explore graph-inspired methods like random walks on meshes and point clouds. These techniques align closely with your interest in graph structures and their computational applications.
#
# 2. **Distributed and Efficient Computing**:
#    - Her research on methods like "PatchContrast" and "GraVoS" deals with computational efficiency in large-scale, high-dimensional data scenarios, which could relate to distributed computing on graphs.
#
# 3. **Deep Learning for Structured Data**:
#    - Projects like "LIMITR" and "k-NNN" demonstrate her interest in leveraging deep learning for structured and relational data, such as those found in graph-based systems.
#
# 4. **Interdisciplinary Applications**:
#    - Professor Tal has applied graph and neural network techniques to diverse fields, including medical imaging (e.g., unpaired medical report generation) and archaeology (e.g., artifact analysis using semi-supervised learning).
#
# ---
#
# ### Why Professor Ayellet Tal Could Be a Great Fit for You:
# 1. **Alignment with Graph-Based Methods**:
#    - Many of her projects involve graph-like structures (e.g., point clouds, meshes) and innovative computational techniques that reflect your interest in graph theory and GNNs.
#
# 2. **Experience in Distributed Learning**:
#    - Her research addresses challenges in distributed and computationally efficient learning, which complements your interest in distributed computing on graphs.
#
# 3. **Strong Foundation in Discrete Mathematics**:
#    - Given your mentoring experience in discrete mathematics, you are well-prepared to engage with the mathematical rigor required for her work on graph-based representations and optimization.
#
# 4. **Track Record of Innovative Applications**:
#    - Professor Tal's interdisciplinary applications of machine learning and graph-based methods in fields like medical imaging and archaeology could provide you with opportunities to work on impactful, real-world problems.
#
# 5. **Supportive Environment for Excellence**:
#    - Her position at the Technion and her role in fostering cutting-edge research make her an excellent mentor for ambitious students like you who have demonstrated excellence through awards such as the Dean's and President’s Excellence Awards.
#
# ---
#
# ### Suggested Next Steps:
# - **Reach Out**: Consider drafting an email to Professor Tal expressing your interest in her work. Highlight your passion for graphs and distributed computing, and mention specific projects of hers that resonate with your interests.
# - **Explore Her Work**: Dive deeper into some of her papers like *CloudWalker*, *MeshWalker*, or *GraVoS* to understand her methodologies and see how you could contribute.
# - **Prepare for Collaboration**: Given your strong algorithmic problem-solving skills and background in discrete mathematics, you might want to propose ideas or share preliminary thoughts on how your skills could intersect with her research.
#
# ---
#
# Professor Ayellet Tal's expertise presents an excellent opportunity for you to explore advanced research in graphs and distributed computing. I encourage you to take the initiative to connect with her and discuss potential research directions.
#
# Let me know if you need help crafting an email or preparing for a discussion. Good luck!
# Generated CV:
# ### **Tailored CV**
#
# **Name:** Yarden Adi
# **Email:** yardn.adi@gmail.com
# **Phone:** 050-6976406
# **LinkedIn:** [https://www.linkedin.com/in/yardn-adi/](https://www.linkedin.com/in/yardn-adi/)
#
# ---
#
# #### **Education:**
# - **B.Sc., Data Science** | Technion, Israel Institute of Technology | 2021–2024
# - **High School** | Rogozin, Kiryat Ata | 2018–2021
#
# ---
#
# #### **Research Experience:**
# - **Aspiration:** Strong interest in graph-based learning, distributed computing on graphs, and Graph Neural Networks (GNNs). Actively exploring opportunities to contribute to research in these areas.
#
# ---
#
# #### **Work Experience:**
# - **Junior Faculty Member** | Technion, Israel Institute of Technology | 2024
#   - Evaluated student exercises and exams in discrete mathematics and visual information presentation and cognition courses at the Data and Decision Sciences faculty.
#
# - **Mentor, Soft Landing Program** | Technion, Israel Institute of Technology | 2023
#   - Provided guidance, advice, and feedback to first-year students at the Data and Decision Sciences faculty to support their initial steps in academia.
#
# ---
#
# #### **Volunteer Experience:**
# - **Member** | Israel’s Olympic Team in Computer Science | Future Scientist Center and Bar-Ilan University | 2020–2021
#   - Specialized in competitive algorithmic problem solving in C++, solving computer science challenges under time constraints.
#   - Practiced problem analysis, creativity, and out-of-the-box thinking.
#   - Participated in courses on algorithms and data structures at Bar-Ilan University.
#
# ---
#
# #### **Publications:**
# - No publications yet. Open to contributing to research projects in graph theory, distributed computing, and GNNs.
#
# ---
#
# #### **Skills:**
# - Algorithmic Problem Solving
# - Data Science
# - C++
# - Discrete Mathematics
# - Visual Data Presentation
# - Guidance/Mentorship
#
# ---
#
# #### **Awards & Achievements:**
# - **Dean's Excellence Award** | Technion, Israel Institute of Technology | 2023
# - **President’s Excellence Award** | Technion, Israel Institute of Technology | 2024
# - **Mayor’s Student Excellence Honor** | Kiryat Ata | 2019, 2021
#
# ---
#
# ### **Notes on Feedback Implementation:**
# 1. **Research Experience Section:** Added a dedicated "aspiration" statement to reflect the user's interest in graph-based learning, distributed computing, and GNNs as a personal goal, not formal experience.
# 2. **Volunteer Experience Adjustment:** Reworded the phrasing about courses on algorithms and data structures to avoid exaggeration, ensuring consistency with the original CV.
# 3. **Publications Section:** A note was included about openness to contributing to research projects, demonstrating proactivity in the absence of publications.
# 4. **Alignment with Supervisor Recommendations:** The CV is tailored to reflect the user's interest in areas relevant to Professor Ayellet Tal's research, such as graph theory and computational efficiency, aligning with potential research opportunities.
#
# This CV is now structured, professional, and ready for submission. Let me know if further adjustments are needed!
# Formulated Email:
# Subject: Inquiry About Potential Research Supervision
#
# Dear Professor Ayellet Tal,
#
# I hope this email finds you well. My name is Yarden Adi, and I am currently completing my B.Sc. in Data Science at the Technion, Israel Institute of Technology. I am writing to express my deep interest in your research, particularly in the areas of graph-based learning, distributed computing, and Graph Neural Networks (GNNs).
#
# My academic background has equipped me with strong skills in algorithmic problem-solving, discrete mathematics, and data science. I have been especially fascinated by the innovative approaches in your works, such as *CloudWalker* and *MeshWalker*, which explore graph-inspired methods for 3D point clouds. These align closely with my passion for understanding and leveraging graph structures in computational applications.
#
# Given my aspirations to contribute to graph-based methods and distributed computing, I would be honored to discuss how my skills and interests could intersect with your research. Would it be possible to schedule a meeting at your convenience to explore potential research opportunities under your guidance?
#
# Thank you for considering my request. I greatly admire your work and would be thrilled to learn from your expertise. I look forward to the possibility of collaborating with you.
#
# Best regards,
# Yarden Adi
# Email: yardn.adi@gmail.com
# Phone: 050-6976406
# LinkedIn: [https://www.linkedin.com/in/yardn-adi/](https://www.linkedin.com/in/yardn-adi/)
# Rejected CV, generating new one
# Supervisor Recommendation:
# Based on your interest in distributed computing and distributed algorithms on graphs, Professor **Shlomo Moran** appears to be a highly suitable supervisor for your research aspirations. Here’s a breakdown of his expertise and how it aligns with your goals:
#
# ---
#
# ### **Supervisor Overview: Professor Shlomo Moran**
# Professor Moran is a prominent researcher with extensive experience in distributed computing, combinatorial algorithms, and dynamic graph problems. His work spans over several decades and includes foundational contributions to distributed algorithms, dynamic network synchronization, and fault tolerance in distributed systems.
#
# ---
#
# ### **Key Research Areas and Expertise**
# 1. **Distributed Algorithms on Graphs:**
#    - Professor Moran has explored problems in distributed computing, such as the *firing squad problem* on dynamic graphs, which parallels your interest in graph-related distributed algorithms.
#    - His research includes synchronization algorithms in dynamic networks and studies on the connectivity requirements for solving distributed coordination challenges.
#
# 2. **Round and Message Complexity:**
#    - He has worked on minimizing the number of communication rounds and messages in distributed systems, as seen in his seminal work on tasks like the *Maximal Independent Set* and *fault-tolerant rumor spreading*. These topics are directly related to your goal of designing efficient algorithms with low-round complexity.
#
# 3. **Fault Tolerance and Consensus:**
#    - His investigations into fault-tolerant rumor spreading and consensus protocols address foundational problems in distributed systems, providing insights into robustness and efficiency.
#
# 4. **Dynamic and Adaptive Algorithms:**
#    - Professor Moran’s studies on dynamic networks and adaptive methods for computational problems highlight his expertise in designing algorithms that adapt to changing conditions—a valuable perspective for tackling distributed problems on graphs.
#
# ---
#
# ### **Why Professor Moran is a Good Fit for You**
# 1. **Alignment with Your Research Interests:**
#    - Your focus on creating distributed algorithms for graph problems, such as Maximal Independent Set, matches Professor Moran’s work on graph algorithms, including his studies on synchronization and consensus in dynamic networks.
#
# 2. **Focus on Efficiency:**
#    - Your emphasis on optimizing rounds and message complexity resonates with Professor Moran’s research ethos, particularly his work on minimizing communication in distributed algorithms.
#
# 3. **Strong Theoretical Foundation:**
#    - Given your academic background and competitive problem-solving experience (e.g., Israel’s Olympic Team in Computer Science), you are well-prepared to engage with the theoretical challenges in Professor Moran’s research areas.
#
# 4. **Opportunity for Growth:**
#    - While your CV indicates limited formal research experience, your achievements in discrete mathematics, algorithmic problem solving, and mentorship showcase a strong foundation that aligns well with Professor Moran’s focus on rigorous and innovative research.
#
# ---
#
# ### **Suggested Next Steps**
# 1. **Engage with His Work:**
#    - Review foundational papers, such as those on the *firing squad problem* and *round complexity of solvable tasks*, to familiarize yourself with his research methodologies.
#    - Explore his work on fault-tolerant algorithms and synchronization in dynamic networks, as these are closely tied to your interests.
#
# 2. **Tailor Your Proposal:**
#    - Emphasize your interest in designing distributed algorithms for graph problems with a focus on low communication overhead and adaptability. Highlight your competitive programming background as evidence of your problem-solving skills.
#
# 3. **Reach Out:**
#    - Contact Professor Moran with a personalized email that outlines your research interests and how they align with his work. Mention specific papers or projects of his that you find inspiring, and propose potential areas for collaboration.
#
# ---
#
# By working with Professor Moran, you will have the opportunity to address cutting-edge problems in distributed computing while benefiting from his deep expertise in the field.
# Generated CV:
# **Final CV**
#
# **Name:** Yarden Adi
# **Email:** yardn.adi@gmail.com
# **Phone:** 050-6976406
# **LinkedIn:** [https://www.linkedin.com/in/yardn-adi/](https://www.linkedin.com/in/yardn-adi/)
#
# ---
#
# #### **Education:**
# - B.Sc., Data Science | Technion, Israel Institute of Technology | 2021–2024
# - High School | Rogozin, Kiryat Ata | 2018–2021
#
# ---
#
# #### **Research Experience:**
# *Currently seeking research opportunities in distributed computing and graph theory to explore distributed algorithms with a focus on low round and message complexity.*
#
# ---
#
# #### **Work Experience:**
# - **Junior Faculty Member** | Technion, Israel Institute of Technology | 2024
#   - Evaluated student exercises and exams in discrete mathematics and visual information presentation and cognition courses at the Data and Decision Sciences faculty.
#
# - **Mentor, Soft Landing Program** | Technion, Israel Institute of Technology | 2023
#   - Provided guidance, advice, and feedback to first-year students at the Data and Decision Sciences faculty to support their initial steps in academia.
#
# ---
#
# #### **Volunteer Experience:**
# - **Member** | Israel’s Olympic Team in Computer Science | Future Scientist Center and Bar-Ilan University | 2020–2021
#   - Specialized in competitive algorithmic problem solving in C++.
#   - Solved computer science challenges under time constraints, practicing problem analysis, creativity, and out-of-the-box thinking.
#   - Participated in courses on algorithms and data structures at Bar-Ilan University.
#
# ---
#
# #### **Skills:**
# - Algorithmic Problem Solving, Data Science, C++, Discrete Mathematics, Visual Data Presentation, Guidance/Mentorship
#
# ---
#
# #### **Awards & Achievements:**
# - Dean's Excellence Award | Technion, Israel Institute of Technology | 2023
# - President’s Excellence Award | Technion, Israel Institute of Technology | 2024
# - Mayor’s Student Excellence Honor | Kiryat Ata | 2019, 2021
#
# ---
#
# #### **Note to Potential Supervisors:**
# I am particularly interested in opportunities that align with my passion for distributed computing and distributed algorithms on graphs. My goal is to design algorithms that solve graph problems, such as the Maximal Independent Set, with low round and message complexity. I am eager to collaborate on innovative research projects that tackle these challenges.
#
# ---
#
# This CV has been revised to ensure it accurately reflects your background and aspirations without introducing speculative or unsupported content.
# Formulated Email:
# Subject: Inquiry About Potential Research Supervision
#
# Dear Professor Moran,
#
# My name is Yarden Adi, and I am currently pursuing a B.Sc. in Data Science at the Technion, Israel Institute of Technology. I am writing to express my strong interest in your work and to explore the possibility of conducting research under your supervision.
#
# My academic interests center on distributed computing and designing distributed algorithms for graph problems, particularly focusing on optimizing round and message complexity. I am keen to explore problems such as the Maximal Independent Set and develop efficient solutions that address these challenges. I have been inspired by your contributions to distributed algorithms and dynamic graph problems, especially your work on synchronization and fault-tolerant rumor spreading, which closely aligns with my aspirations.
#
# I would greatly appreciate the opportunity to meet with you to discuss my research interests and learn more about potential collaboration opportunities. Please let me know if you would be available for a meeting at your convenience.
#
# Thank you for considering my request, and I look forward to the possibility of working under your guidance.
#
# Best regards,
# Yarden Adi
# Email: yardn.adi@gmail.com
# Phone: 050-6976406
# [LinkedIn Profile](https://www.linkedin.com/in/yardn-adi/)
